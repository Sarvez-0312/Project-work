# %% [markdown]
# ## DENCE NET ARCHITECTURE

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import tensorflow
import tensorflow as tf
print(tf.__version__)

import keras
import keras.backend as K
from keras.models import Model
from keras.layers import Input, Dense, Conv2D, Conv3D, DepthwiseConv2D, SeparableConv2D, Conv3DTranspose
from keras.layers import Flatten, MaxPool2D, AvgPool2D, GlobalAvgPool2D, UpSampling2D, BatchNormalization
from keras.layers import Concatenate, Add, Dropout, ReLU, Lambda, Activation, LeakyReLU, PReLU



from time import time
import numpy as np

from keras.callbacks import ModelCheckpoint
from tensorflow.keras.callbacks import EarlyStopping

import warnings
warnings.filterwarnings('ignore')
# Out:
# WARNING:tensorflow:From D:\ANACONDA\envs\pr\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# 2.15.0

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train=ImageDataGenerator(rescale=1./255,shear_range=0.2,zoom_range=0.2,horizontal_flip=True,validation_split = 0.2)
train_data=train.flow_from_directory(directory = 'Dataset',target_size=(224,224),
                                     batch_size=32,class_mode='categorical')
# Out:
# Found 1336 images belonging to 9 classes.

# %%
test=ImageDataGenerator(rescale=1./255)
test_data=test.flow_from_directory(directory = 'Dataset',target_size=(224,224),
                                   batch_size=32,class_mode='categorical')
# Out:
# Found 1336 images belonging to 9 classes.

# %%
def densenet(img_shape, n_classes, f=32):
  repetitions = 6, 12, 24, 16
  
  def bn_rl_conv(x, f, k=1, s=1, p='same'):
    x = BatchNormalization()(x)
    x = ReLU()(x)
    x = Conv2D(f, k, strides=s, padding=p)(x)
    return x
  
  
  def dense_block(tensor, r):
    for _ in range(r):
      x = bn_rl_conv(tensor, 4*f)
      x = bn_rl_conv(x, f, 3)
      tensor = Concatenate()([tensor, x])
    return tensor
  
  
  def transition_block(x):
    x = bn_rl_conv(x, K.int_shape(x)[-1] // 2)
    x = AvgPool2D(2, strides=2, padding='same')(x)
    return x
  
  
  input = Input(img_shape)
  
  x = Conv2D(64, 7, strides=2, padding='same')(input)
  x = MaxPool2D(3, strides=2, padding='same')(x)
  
  for r in repetitions:
    d = dense_block(x, r)
    x = transition_block(d)
  
  x = GlobalAvgPool2D()(d)
  
  output = Dense(n_classes, activation='softmax')(x)
  
  model = Model(input, output)
  model.compile(optimizer='Adam',loss='categorical_crossentropy',metrics=['accuracy',tensorflow.keras.metrics.Precision()])
  return model
     

input_shape = 224, 224, 3
n_classes = 9

K.clear_session()
model = densenet(input_shape, n_classes)
model.summary()
# Out:
# WARNING:tensorflow:From D:\ANACONDA\envs\pr\lib\site-packages\keras\src\backend.py:277: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# WARNING:tensorflow:From D:\ANACONDA\envs\pr\lib\site-packages\keras\src\layers\pooling\max_pooling2d.py:161: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From D:\ANACONDA\envs\pr\lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  conv2d (Conv2D)             (None, 112, 112, 64)         9472      ['input_1[0][0]']
#
#  max_pooling2d (MaxPooling2  (None, 56, 56, 64)           0         ['conv2d[0][0]']
#  D)
#
#  batch_normalization (Batch  (None, 56, 56, 64)           256       ['max_pooling2d[0][0]']
#  Normalization)
#
#  re_lu (ReLU)                (None, 56, 56, 64)           0         ['batch_normalization[0][0]']
#
#  conv2d_1 (Conv2D)           (None, 56, 56, 128)          8320      ['re_lu[0][0]']
#
#  batch_normalization_1 (Bat  (None, 56, 56, 128)          512       ['conv2d_1[0][0]']
#  chNormalization)
#
#  re_lu_1 (ReLU)              (None, 56, 56, 128)          0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  conv2d_2 (Conv2D)           (None, 56, 56, 32)           36896     ['re_lu_1[0][0]']
#
#  concatenate (Concatenate)   (None, 56, 56, 96)           0         ['max_pooling2d[0][0]',
#                                                                      'conv2d_2[0][0]']
#
#  batch_normalization_2 (Bat  (None, 56, 56, 96)           384       ['concatenate[0][0]']
#  chNormalization)
#
#  re_lu_2 (ReLU)              (None, 56, 56, 96)           0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  conv2d_3 (Conv2D)           (None, 56, 56, 128)          12416     ['re_lu_2[0][0]']
#
#  batch_normalization_3 (Bat  (None, 56, 56, 128)          512       ['conv2d_3[0][0]']
#  chNormalization)
#
#  re_lu_3 (ReLU)              (None, 56, 56, 128)          0         ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  conv2d_4 (Conv2D)           (None, 56, 56, 32)           36896     ['re_lu_3[0][0]']
#
#  concatenate_1 (Concatenate  (None, 56, 56, 128)          0         ['concatenate[0][0]',
#  )                                                                   'conv2d_4[0][0]']
#
#  batch_normalization_4 (Bat  (None, 56, 56, 128)          512       ['concatenate_1[0][0]']
#  chNormalization)
#
#  re_lu_4 (ReLU)              (None, 56, 56, 128)          0         ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  conv2d_5 (Conv2D)           (None, 56, 56, 128)          16512     ['re_lu_4[0][0]']
#
#  batch_normalization_5 (Bat  (None, 56, 56, 128)          512       ['conv2d_5[0][0]']
#  chNormalization)
#
#  re_lu_5 (ReLU)              (None, 56, 56, 128)          0         ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  conv2d_6 (Conv2D)           (None, 56, 56, 32)           36896     ['re_lu_5[0][0]']
#
#  concatenate_2 (Concatenate  (None, 56, 56, 160)          0         ['concatenate_1[0][0]',
#  )                                                                   'conv2d_6[0][0]']
#
#  batch_normalization_6 (Bat  (None, 56, 56, 160)          640       ['concatenate_2[0][0]']
#  chNormalization)
#
#  re_lu_6 (ReLU)              (None, 56, 56, 160)          0         ['batch_normalization_6[0][0]'
#                                                                     ]
#
#  conv2d_7 (Conv2D)           (None, 56, 56, 128)          20608     ['re_lu_6[0][0]']
#
#  batch_normalization_7 (Bat  (None, 56, 56, 128)          512       ['conv2d_7[0][0]']
#  chNormalization)
#
#  re_lu_7 (ReLU)              (None, 56, 56, 128)          0         ['batch_normalization_7[0][0]'
#                                                                     ]
#
#  conv2d_8 (Conv2D)           (None, 56, 56, 32)           36896     ['re_lu_7[0][0]']
#
#  concatenate_3 (Concatenate  (None, 56, 56, 192)          0         ['concatenate_2[0][0]',
#  )                                                                   'conv2d_8[0][0]']
#
#  batch_normalization_8 (Bat  (None, 56, 56, 192)          768       ['concatenate_3[0][0]']
#  chNormalization)
#
#  re_lu_8 (ReLU)              (None, 56, 56, 192)          0         ['batch_normalization_8[0][0]'
#                                                                     ]
#
#  conv2d_9 (Conv2D)           (None, 56, 56, 128)          24704     ['re_lu_8[0][0]']
#
#  batch_normalization_9 (Bat  (None, 56, 56, 128)          512       ['conv2d_9[0][0]']
#  chNormalization)
#
#  re_lu_9 (ReLU)              (None, 56, 56, 128)          0         ['batch_normalization_9[0][0]'
#                                                                     ]
#
#  conv2d_10 (Conv2D)          (None, 56, 56, 32)           36896     ['re_lu_9[0][0]']
#
#  concatenate_4 (Concatenate  (None, 56, 56, 224)          0         ['concatenate_3[0][0]',
#  )                                                                   'conv2d_10[0][0]']
#
#  batch_normalization_10 (Ba  (None, 56, 56, 224)          896       ['concatenate_4[0][0]']
#  tchNormalization)
#
#  re_lu_10 (ReLU)             (None, 56, 56, 224)          0         ['batch_normalization_10[0][0]
#                                                                     ']
#
#  conv2d_11 (Conv2D)          (None, 56, 56, 128)          28800     ['re_lu_10[0][0]']
#
#  batch_normalization_11 (Ba  (None, 56, 56, 128)          512       ['conv2d_11[0][0]']
#  tchNormalization)
#
#  re_lu_11 (ReLU)             (None, 56, 56, 128)          0         ['batch_normalization_11[0][0]
#                                                                     ']
#
#  conv2d_12 (Conv2D)          (None, 56, 56, 32)           36896     ['re_lu_11[0][0]']
#
#  concatenate_5 (Concatenate  (None, 56, 56, 256)          0         ['concatenate_4[0][0]',
#  )                                                                   'conv2d_12[0][0]']
#
#  batch_normalization_12 (Ba  (None, 56, 56, 256)          1024      ['concatenate_5[0][0]']
#  tchNormalization)
#
#  re_lu_12 (ReLU)             (None, 56, 56, 256)          0         ['batch_normalization_12[0][0]
#                                                                     ']
#
#  conv2d_13 (Conv2D)          (None, 56, 56, 128)          32896     ['re_lu_12[0][0]']
#
#  average_pooling2d (Average  (None, 28, 28, 128)          0         ['conv2d_13[0][0]']
#  Pooling2D)
#
#  batch_normalization_13 (Ba  (None, 28, 28, 128)          512       ['average_pooling2d[0][0]']
#  tchNormalization)
#
#  re_lu_13 (ReLU)             (None, 28, 28, 128)          0         ['batch_normalization_13[0][0]
#                                                                     ']
#
#  conv2d_14 (Conv2D)          (None, 28, 28, 128)          16512     ['re_lu_13[0][0]']
#
#  batch_normalization_14 (Ba  (None, 28, 28, 128)          512       ['conv2d_14[0][0]']
#  tchNormalization)
#
#  re_lu_14 (ReLU)             (None, 28, 28, 128)          0         ['batch_normalization_14[0][0]
#                                                                     ']
#
#  conv2d_15 (Conv2D)          (None, 28, 28, 32)           36896     ['re_lu_14[0][0]']
#
#  concatenate_6 (Concatenate  (None, 28, 28, 160)          0         ['average_pooling2d[0][0]',
#  )                                                                   'conv2d_15[0][0]']
#
#  batch_normalization_15 (Ba  (None, 28, 28, 160)          640       ['concatenate_6[0][0]']
#  tchNormalization)
#
#  re_lu_15 (ReLU)             (None, 28, 28, 160)          0         ['batch_normalization_15[0][0]
#                                                                     ']
#
#  conv2d_16 (Conv2D)          (None, 28, 28, 128)          20608     ['re_lu_15[0][0]']
#
#  batch_normalization_16 (Ba  (None, 28, 28, 128)          512       ['conv2d_16[0][0]']
#  tchNormalization)
#
#  re_lu_16 (ReLU)             (None, 28, 28, 128)          0         ['batch_normalization_16[0][0]
#                                                                     ']
#
#  conv2d_17 (Conv2D)          (None, 28, 28, 32)           36896     ['re_lu_16[0][0]']
#
#  concatenate_7 (Concatenate  (None, 28, 28, 192)          0         ['concatenate_6[0][0]',
#  )                                                                   'conv2d_17[0][0]']
#
#  batch_normalization_17 (Ba  (None, 28, 28, 192)          768       ['concatenate_7[0][0]']
#  tchNormalization)
#
#  re_lu_17 (ReLU)             (None, 28, 28, 192)          0         ['batch_normalization_17[0][0]
#                                                                     ']
#
#  conv2d_18 (Conv2D)          (None, 28, 28, 128)          24704     ['re_lu_17[0][0]']
#
#  batch_normalization_18 (Ba  (None, 28, 28, 128)          512       ['conv2d_18[0][0]']
#  tchNormalization)
#
#  re_lu_18 (ReLU)             (None, 28, 28, 128)          0         ['batch_normalization_18[0][0]
#                                                                     ']
#
#  conv2d_19 (Conv2D)          (None, 28, 28, 32)           36896     ['re_lu_18[0][0]']
#
#  concatenate_8 (Concatenate  (None, 28, 28, 224)          0         ['concatenate_7[0][0]',
#  )                                                                   'conv2d_19[0][0]']
#
#  batch_normalization_19 (Ba  (None, 28, 28, 224)          896       ['concatenate_8[0][0]']
#  tchNormalization)
#
#  re_lu_19 (ReLU)             (None, 28, 28, 224)          0         ['batch_normalization_19[0][0]
#                                                                     ']
#
#  conv2d_20 (Conv2D)          (None, 28, 28, 128)          28800     ['re_lu_19[0][0]']
#
#  batch_normalization_20 (Ba  (None, 28, 28, 128)          512       ['conv2d_20[0][0]']
#  tchNormalization)
#
#  re_lu_20 (ReLU)             (None, 28, 28, 128)          0         ['batch_normalization_20[0][0]
#                                                                     ']
#
#  conv2d_21 (Conv2D)          (None, 28, 28, 32)           36896     ['re_lu_20[0][0]']
#
#  concatenate_9 (Concatenate  (None, 28, 28, 256)          0         ['concatenate_8[0][0]',
#  )                                                                   'conv2d_21[0][0]']
#
#  batch_normalization_21 (Ba  (None, 28, 28, 256)          1024      ['concatenate_9[0][0]']
#  tchNormalization)
#
#  re_lu_21 (ReLU)             (None, 28, 28, 256)          0         ['batch_normalization_21[0][0]
#                                                                     ']
#
#  conv2d_22 (Conv2D)          (None, 28, 28, 128)          32896     ['re_lu_21[0][0]']
#
#  batch_normalization_22 (Ba  (None, 28, 28, 128)          512       ['conv2d_22[0][0]']
#  tchNormalization)
#
#  re_lu_22 (ReLU)             (None, 28, 28, 128)          0         ['batch_normalization_22[0][0]
#                                                                     ']
#
#  conv2d_23 (Conv2D)          (None, 28, 28, 32)           36896     ['re_lu_22[0][0]']
#
#  concatenate_10 (Concatenat  (None, 28, 28, 288)          0         ['concatenate_9[0][0]',
#  e)                                                                  'conv2d_23[0][0]']
#
#  batch_normalization_23 (Ba  (None, 28, 28, 288)          1152      ['concatenate_10[0][0]']
#  tchNormalization)
#
#  re_lu_23 (ReLU)             (None, 28, 28, 288)          0         ['batch_normalization_23[0][0]
#                                                                     ']
#
#  conv2d_24 (Conv2D)          (None, 28, 28, 128)          36992     ['re_lu_23[0][0]']
#
#  batch_normalization_24 (Ba  (None, 28, 28, 128)          512       ['conv2d_24[0][0]']
#  tchNormalization)
#
#  re_lu_24 (ReLU)             (None, 28, 28, 128)          0         ['batch_normalization_24[0][0]
#                                                                     ']
#
#  conv2d_25 (Conv2D)          (None, 28, 28, 32)           36896     ['re_lu_24[0][0]']
#
#  concatenate_11 (Concatenat  (None, 28, 28, 320)          0         ['concatenate_10[0][0]',
#  e)                                                                  'conv2d_25[0][0]']
#
#  batch_normalization_25 (Ba  (None, 28, 28, 320)          1280      ['concatenate_11[0][0]']
#  tchNormalization)
#
#  re_lu_25 (ReLU)             (None, 28, 28, 320)          0         ['batch_normalization_25[0][0]
#                                                                     ']
#
#  conv2d_26 (Conv2D)          (None, 28, 28, 128)          41088     ['re_lu_25[0][0]']
#
#  batch_normalization_26 (Ba  (None, 28, 28, 128)          512       ['conv2d_26[0][0]']
#  tchNormalization)
#
#  re_lu_26 (ReLU)             (None, 28, 28, 128)          0         ['batch_normalization_26[0][0]
#                                                                     ']
#
#  conv2d_27 (Conv2D)          (None, 28, 28, 32)           36896     ['re_lu_26[0][0]']
#
#  concatenate_12 (Concatenat  (None, 28, 28, 352)          0         ['concatenate_11[0][0]',
#  e)                                                                  'conv2d_27[0][0]']
#
#  batch_normalization_27 (Ba  (None, 28, 28, 352)          1408      ['concatenate_12[0][0]']
#  tchNormalization)
#
#  re_lu_27 (ReLU)             (None, 28, 28, 352)          0         ['batch_normalization_27[0][0]
#                                                                     ']
#
#  conv2d_28 (Conv2D)          (None, 28, 28, 128)          45184     ['re_lu_27[0][0]']
#
#  batch_normalization_28 (Ba  (None, 28, 28, 128)          512       ['conv2d_28[0][0]']
#  tchNormalization)
#
#  re_lu_28 (ReLU)             (None, 28, 28, 128)          0         ['batch_normalization_28[0][0]
#                                                                     ']
#
#  conv2d_29 (Conv2D)          (None, 28, 28, 32)           36896     ['re_lu_28[0][0]']
#
#  concatenate_13 (Concatenat  (None, 28, 28, 384)          0         ['concatenate_12[0][0]',
#  e)                                                                  'conv2d_29[0][0]']
#
#  batch_normalization_29 (Ba  (None, 28, 28, 384)          1536      ['concatenate_13[0][0]']
#  tchNormalization)
#
#  re_lu_29 (ReLU)             (None, 28, 28, 384)          0         ['batch_normalization_29[0][0]
#                                                                     ']
#
#  conv2d_30 (Conv2D)          (None, 28, 28, 128)          49280     ['re_lu_29[0][0]']
#
#  batch_normalization_30 (Ba  (None, 28, 28, 128)          512       ['conv2d_30[0][0]']
#  tchNormalization)
#
#  re_lu_30 (ReLU)             (None, 28, 28, 128)          0         ['batch_normalization_30[0][0]
#                                                                     ']
#
#  conv2d_31 (Conv2D)          (None, 28, 28, 32)           36896     ['re_lu_30[0][0]']
#
#  concatenate_14 (Concatenat  (None, 28, 28, 416)          0         ['concatenate_13[0][0]',
#  e)                                                                  'conv2d_31[0][0]']
#
#  batch_normalization_31 (Ba  (None, 28, 28, 416)          1664      ['concatenate_14[0][0]']
#  tchNormalization)
#
#  re_lu_31 (ReLU)             (None, 28, 28, 416)          0         ['batch_normalization_31[0][0]
#                                                                     ']
#
#  conv2d_32 (Conv2D)          (None, 28, 28, 128)          53376     ['re_lu_31[0][0]']
#
#  batch_normalization_32 (Ba  (None, 28, 28, 128)          512       ['conv2d_32[0][0]']
#  tchNormalization)
#
#  re_lu_32 (ReLU)             (None, 28, 28, 128)          0         ['batch_normalization_32[0][0]
#                                                                     ']
#
#  conv2d_33 (Conv2D)          (None, 28, 28, 32)           36896     ['re_lu_32[0][0]']
#
#  concatenate_15 (Concatenat  (None, 28, 28, 448)          0         ['concatenate_14[0][0]',
#  e)                                                                  'conv2d_33[0][0]']
#
#  batch_normalization_33 (Ba  (None, 28, 28, 448)          1792      ['concatenate_15[0][0]']
#  tchNormalization)
#
#  re_lu_33 (ReLU)             (None, 28, 28, 448)          0         ['batch_normalization_33[0][0]
#                                                                     ']
#
#  conv2d_34 (Conv2D)          (None, 28, 28, 128)          57472     ['re_lu_33[0][0]']
#
#  batch_normalization_34 (Ba  (None, 28, 28, 128)          512       ['conv2d_34[0][0]']
#  tchNormalization)
#
#  re_lu_34 (ReLU)             (None, 28, 28, 128)          0         ['batch_normalization_34[0][0]
#                                                                     ']
#
#  conv2d_35 (Conv2D)          (None, 28, 28, 32)           36896     ['re_lu_34[0][0]']
#
#  concatenate_16 (Concatenat  (None, 28, 28, 480)          0         ['concatenate_15[0][0]',
#  e)                                                                  'conv2d_35[0][0]']
#
#  batch_normalization_35 (Ba  (None, 28, 28, 480)          1920      ['concatenate_16[0][0]']
#  tchNormalization)
#
#  re_lu_35 (ReLU)             (None, 28, 28, 480)          0         ['batch_normalization_35[0][0]
#                                                                     ']
#
#  conv2d_36 (Conv2D)          (None, 28, 28, 128)          61568     ['re_lu_35[0][0]']
#
#  batch_normalization_36 (Ba  (None, 28, 28, 128)          512       ['conv2d_36[0][0]']
#  tchNormalization)
#
#  re_lu_36 (ReLU)             (None, 28, 28, 128)          0         ['batch_normalization_36[0][0]
#                                                                     ']
#
#  conv2d_37 (Conv2D)          (None, 28, 28, 32)           36896     ['re_lu_36[0][0]']
#
#  concatenate_17 (Concatenat  (None, 28, 28, 512)          0         ['concatenate_16[0][0]',
#  e)                                                                  'conv2d_37[0][0]']
#
#  batch_normalization_37 (Ba  (None, 28, 28, 512)          2048      ['concatenate_17[0][0]']
#  tchNormalization)
#
#  re_lu_37 (ReLU)             (None, 28, 28, 512)          0         ['batch_normalization_37[0][0]
#                                                                     ']
#
#  conv2d_38 (Conv2D)          (None, 28, 28, 256)          131328    ['re_lu_37[0][0]']
#
#  average_pooling2d_1 (Avera  (None, 14, 14, 256)          0         ['conv2d_38[0][0]']
#  gePooling2D)
#
#  batch_normalization_38 (Ba  (None, 14, 14, 256)          1024      ['average_pooling2d_1[0][0]']
#  tchNormalization)
#
#  re_lu_38 (ReLU)             (None, 14, 14, 256)          0         ['batch_normalization_38[0][0]
#                                                                     ']
#
#  conv2d_39 (Conv2D)          (None, 14, 14, 128)          32896     ['re_lu_38[0][0]']
#
#  batch_normalization_39 (Ba  (None, 14, 14, 128)          512       ['conv2d_39[0][0]']
#  tchNormalization)
#
#  re_lu_39 (ReLU)             (None, 14, 14, 128)          0         ['batch_normalization_39[0][0]
#                                                                     ']
#
#  conv2d_40 (Conv2D)          (None, 14, 14, 32)           36896     ['re_lu_39[0][0]']
#
#  concatenate_18 (Concatenat  (None, 14, 14, 288)          0         ['average_pooling2d_1[0][0]',
#  e)                                                                  'conv2d_40[0][0]']
#
#  batch_normalization_40 (Ba  (None, 14, 14, 288)          1152      ['concatenate_18[0][0]']
#  tchNormalization)
#
#  re_lu_40 (ReLU)             (None, 14, 14, 288)          0         ['batch_normalization_40[0][0]
#                                                                     ']
#
#  conv2d_41 (Conv2D)          (None, 14, 14, 128)          36992     ['re_lu_40[0][0]']
#
#  batch_normalization_41 (Ba  (None, 14, 14, 128)          512       ['conv2d_41[0][0]']
#  tchNormalization)
#
#  re_lu_41 (ReLU)             (None, 14, 14, 128)          0         ['batch_normalization_41[0][0]
#                                                                     ']
#
#  conv2d_42 (Conv2D)          (None, 14, 14, 32)           36896     ['re_lu_41[0][0]']
#
#  concatenate_19 (Concatenat  (None, 14, 14, 320)          0         ['concatenate_18[0][0]',
#  e)                                                                  'conv2d_42[0][0]']
#
#  batch_normalization_42 (Ba  (None, 14, 14, 320)          1280      ['concatenate_19[0][0]']
#  tchNormalization)
#
#  re_lu_42 (ReLU)             (None, 14, 14, 320)          0         ['batch_normalization_42[0][0]
#                                                                     ']
#
#  conv2d_43 (Conv2D)          (None, 14, 14, 128)          41088     ['re_lu_42[0][0]']
#
#  batch_normalization_43 (Ba  (None, 14, 14, 128)          512       ['conv2d_43[0][0]']
#  tchNormalization)
#
#  re_lu_43 (ReLU)             (None, 14, 14, 128)          0         ['batch_normalization_43[0][0]
#                                                                     ']
#
#  conv2d_44 (Conv2D)          (None, 14, 14, 32)           36896     ['re_lu_43[0][0]']
#
#  concatenate_20 (Concatenat  (None, 14, 14, 352)          0         ['concatenate_19[0][0]',
#  e)                                                                  'conv2d_44[0][0]']
#
#  batch_normalization_44 (Ba  (None, 14, 14, 352)          1408      ['concatenate_20[0][0]']
#  tchNormalization)
#
#  re_lu_44 (ReLU)             (None, 14, 14, 352)          0         ['batch_normalization_44[0][0]
#                                                                     ']
#
#  conv2d_45 (Conv2D)          (None, 14, 14, 128)          45184     ['re_lu_44[0][0]']
#
#  batch_normalization_45 (Ba  (None, 14, 14, 128)          512       ['conv2d_45[0][0]']
#  tchNormalization)
#
#  re_lu_45 (ReLU)             (None, 14, 14, 128)          0         ['batch_normalization_45[0][0]
#                                                                     ']
#
#  conv2d_46 (Conv2D)          (None, 14, 14, 32)           36896     ['re_lu_45[0][0]']
#
#  concatenate_21 (Concatenat  (None, 14, 14, 384)          0         ['concatenate_20[0][0]',
#  e)                                                                  'conv2d_46[0][0]']
#
#  batch_normalization_46 (Ba  (None, 14, 14, 384)          1536      ['concatenate_21[0][0]']
#  tchNormalization)
#
#  re_lu_46 (ReLU)             (None, 14, 14, 384)          0         ['batch_normalization_46[0][0]
#                                                                     ']
#
#  conv2d_47 (Conv2D)          (None, 14, 14, 128)          49280     ['re_lu_46[0][0]']
#
#  batch_normalization_47 (Ba  (None, 14, 14, 128)          512       ['conv2d_47[0][0]']
#  tchNormalization)
#
#  re_lu_47 (ReLU)             (None, 14, 14, 128)          0         ['batch_normalization_47[0][0]
#                                                                     ']
#
#  conv2d_48 (Conv2D)          (None, 14, 14, 32)           36896     ['re_lu_47[0][0]']
#
#  concatenate_22 (Concatenat  (None, 14, 14, 416)          0         ['concatenate_21[0][0]',
#  e)                                                                  'conv2d_48[0][0]']
#
#  batch_normalization_48 (Ba  (None, 14, 14, 416)          1664      ['concatenate_22[0][0]']
#  tchNormalization)
#
#  re_lu_48 (ReLU)             (None, 14, 14, 416)          0         ['batch_normalization_48[0][0]
#                                                                     ']
#
#  conv2d_49 (Conv2D)          (None, 14, 14, 128)          53376     ['re_lu_48[0][0]']
#
#  batch_normalization_49 (Ba  (None, 14, 14, 128)          512       ['conv2d_49[0][0]']
#  tchNormalization)
# ...
#  batch_normalization_101 (Batch  (None, 7, 7, 736)   2944        ['concatenate_48[0][0]']
#  Normalization)
#
#  re_lu_101 (ReLU)               (None, 7, 7, 736)    0           ['batch_normalization_101[0][0]']
#
#  conv2d_102 (Conv2D)            (None, 7, 7, 128)    94336       ['re_lu_101[0][0]']
#
#  batch_normalization_102 (Batch  (None, 7, 7, 128)   512         ['conv2d_102[0][0]']
#  Normalization)
#
#  re_lu_102 (ReLU)               (None, 7, 7, 128)    0           ['batch_normalization_102[0][0]']
#
#  conv2d_103 (Conv2D)            (None, 7, 7, 32)     36896       ['re_lu_102[0][0]']
#
#  concatenate_49 (Concatenate)   (None, 7, 7, 768)    0           ['concatenate_48[0][0]',
#                                                                   'conv2d_103[0][0]']
#
#  batch_normalization_103 (Batch  (None, 7, 7, 768)   3072        ['concatenate_49[0][0]']
#  Normalization)
#
#  re_lu_103 (ReLU)               (None, 7, 7, 768)    0           ['batch_normalization_103[0][0]']
#
#  conv2d_104 (Conv2D)            (None, 7, 7, 128)    98432       ['re_lu_103[0][0]']
#
#  batch_normalization_104 (Batch  (None, 7, 7, 128)   512         ['conv2d_104[0][0]']
#  Normalization)
#
#  re_lu_104 (ReLU)               (None, 7, 7, 128)    0           ['batch_normalization_104[0][0]']
#
#  conv2d_105 (Conv2D)            (None, 7, 7, 32)     36896       ['re_lu_104[0][0]']
#
#  concatenate_50 (Concatenate)   (None, 7, 7, 800)    0           ['concatenate_49[0][0]',
#                                                                   'conv2d_105[0][0]']
#
#  batch_normalization_105 (Batch  (None, 7, 7, 800)   3200        ['concatenate_50[0][0]']
#  Normalization)
#
#  re_lu_105 (ReLU)               (None, 7, 7, 800)    0           ['batch_normalization_105[0][0]']
#
#  conv2d_106 (Conv2D)            (None, 7, 7, 128)    102528      ['re_lu_105[0][0]']
#
#  batch_normalization_106 (Batch  (None, 7, 7, 128)   512         ['conv2d_106[0][0]']
#  Normalization)
#
#  re_lu_106 (ReLU)               (None, 7, 7, 128)    0           ['batch_normalization_106[0][0]']
#
#  conv2d_107 (Conv2D)            (None, 7, 7, 32)     36896       ['re_lu_106[0][0]']
#
#  concatenate_51 (Concatenate)   (None, 7, 7, 832)    0           ['concatenate_50[0][0]',
#                                                                   'conv2d_107[0][0]']
#
#  batch_normalization_107 (Batch  (None, 7, 7, 832)   3328        ['concatenate_51[0][0]']
#  Normalization)
#
#  re_lu_107 (ReLU)               (None, 7, 7, 832)    0           ['batch_normalization_107[0][0]']
#
#  conv2d_108 (Conv2D)            (None, 7, 7, 128)    106624      ['re_lu_107[0][0]']
#
#  batch_normalization_108 (Batch  (None, 7, 7, 128)   512         ['conv2d_108[0][0]']
#  Normalization)
#
#  re_lu_108 (ReLU)               (None, 7, 7, 128)    0           ['batch_normalization_108[0][0]']
#
#  conv2d_109 (Conv2D)            (None, 7, 7, 32)     36896       ['re_lu_108[0][0]']
#
#  concatenate_52 (Concatenate)   (None, 7, 7, 864)    0           ['concatenate_51[0][0]',
#                                                                   'conv2d_109[0][0]']
#
#  batch_normalization_109 (Batch  (None, 7, 7, 864)   3456        ['concatenate_52[0][0]']
#  Normalization)
#
#  re_lu_109 (ReLU)               (None, 7, 7, 864)    0           ['batch_normalization_109[0][0]']
#
#  conv2d_110 (Conv2D)            (None, 7, 7, 128)    110720      ['re_lu_109[0][0]']
#
#  batch_normalization_110 (Batch  (None, 7, 7, 128)   512         ['conv2d_110[0][0]']
#  Normalization)
#
#  re_lu_110 (ReLU)               (None, 7, 7, 128)    0           ['batch_normalization_110[0][0]']
#
#  conv2d_111 (Conv2D)            (None, 7, 7, 32)     36896       ['re_lu_110[0][0]']
#
#  concatenate_53 (Concatenate)   (None, 7, 7, 896)    0           ['concatenate_52[0][0]',
#                                                                   'conv2d_111[0][0]']
#
#  batch_normalization_111 (Batch  (None, 7, 7, 896)   3584        ['concatenate_53[0][0]']
#  Normalization)
#
#  re_lu_111 (ReLU)               (None, 7, 7, 896)    0           ['batch_normalization_111[0][0]']
#
#  conv2d_112 (Conv2D)            (None, 7, 7, 128)    114816      ['re_lu_111[0][0]']
#
#  batch_normalization_112 (Batch  (None, 7, 7, 128)   512         ['conv2d_112[0][0]']
#  Normalization)
#
#  re_lu_112 (ReLU)               (None, 7, 7, 128)    0           ['batch_normalization_112[0][0]']
#
#  conv2d_113 (Conv2D)            (None, 7, 7, 32)     36896       ['re_lu_112[0][0]']
#
#  concatenate_54 (Concatenate)   (None, 7, 7, 928)    0           ['concatenate_53[0][0]',
#                                                                   'conv2d_113[0][0]']
#
#  batch_normalization_113 (Batch  (None, 7, 7, 928)   3712        ['concatenate_54[0][0]']
#  Normalization)
#
#  re_lu_113 (ReLU)               (None, 7, 7, 928)    0           ['batch_normalization_113[0][0]']
#
#  conv2d_114 (Conv2D)            (None, 7, 7, 128)    118912      ['re_lu_113[0][0]']
#
#  batch_normalization_114 (Batch  (None, 7, 7, 128)   512         ['conv2d_114[0][0]']
#  Normalization)
#
#  re_lu_114 (ReLU)               (None, 7, 7, 128)    0           ['batch_normalization_114[0][0]']
#
#  conv2d_115 (Conv2D)            (None, 7, 7, 32)     36896       ['re_lu_114[0][0]']
#
#  concatenate_55 (Concatenate)   (None, 7, 7, 960)    0           ['concatenate_54[0][0]',
#                                                                   'conv2d_115[0][0]']
#
#  batch_normalization_115 (Batch  (None, 7, 7, 960)   3840        ['concatenate_55[0][0]']
#  Normalization)
#
#  re_lu_115 (ReLU)               (None, 7, 7, 960)    0           ['batch_normalization_115[0][0]']
#
#  conv2d_116 (Conv2D)            (None, 7, 7, 128)    123008      ['re_lu_115[0][0]']
#
#  batch_normalization_116 (Batch  (None, 7, 7, 128)   512         ['conv2d_116[0][0]']
#  Normalization)
#
#  re_lu_116 (ReLU)               (None, 7, 7, 128)    0           ['batch_normalization_116[0][0]']
#
#  conv2d_117 (Conv2D)            (None, 7, 7, 32)     36896       ['re_lu_116[0][0]']
#
#  concatenate_56 (Concatenate)   (None, 7, 7, 992)    0           ['concatenate_55[0][0]',
#                                                                   'conv2d_117[0][0]']
#
#  batch_normalization_117 (Batch  (None, 7, 7, 992)   3968        ['concatenate_56[0][0]']
#  Normalization)
#
#  re_lu_117 (ReLU)               (None, 7, 7, 992)    0           ['batch_normalization_117[0][0]']
#
#  conv2d_118 (Conv2D)            (None, 7, 7, 128)    127104      ['re_lu_117[0][0]']
#
#  batch_normalization_118 (Batch  (None, 7, 7, 128)   512         ['conv2d_118[0][0]']
#  Normalization)
#
#  re_lu_118 (ReLU)               (None, 7, 7, 128)    0           ['batch_normalization_118[0][0]']
#
#  conv2d_119 (Conv2D)            (None, 7, 7, 32)     36896       ['re_lu_118[0][0]']
#
#  concatenate_57 (Concatenate)   (None, 7, 7, 1024)   0           ['concatenate_56[0][0]',
#                                                                   'conv2d_119[0][0]']
#
#  global_average_pooling2d (Glob  (None, 1024)        0           ['concatenate_57[0][0]']
#  alAveragePooling2D)
#
#  dense (Dense)                  (None, 5)            5125        ['global_average_pooling2d[0][0]'
#                                                                  ]
#
# ==================================================================================================
# Total params: 7,048,517
# Trainable params: 6,967,045
# Non-trainable params: 81,472
# __________________________________________________________________________________________________

# %%
model_path = "DENCE.h5"

from keras.callbacks import ModelCheckpoint

M = ModelCheckpoint(model_path, monitor='accuracy', verbose=1, save_best_only=True)

# %%
epochs = 50
batch_size = 512

# %%
#### Fitting the model
history = model.fit(
           train_data, steps_per_epoch=train_data.samples // batch_size, 
           epochs=epochs, 
           validation_data=test_data,validation_steps=test_data.samples // batch_size,
           callbacks=[M])
# Out:
# Epoch 1/50
# WARNING:tensorflow:From D:\ANACONDA\envs\pr\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From D:\ANACONDA\envs\pr\lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 2/2 [==============================] - ETA: 0s - loss: 3.9596 - accuracy: 0.2031 - precision: 0.2500
# Epoch 1: accuracy improved from -inf to 0.20312, saving model to DENCE.h5
# 2/2 [==============================] - 60s 15s/step - loss: 3.9596 - accuracy: 0.2031 - precision: 0.2500 - val_loss: 2.1059 - val_accuracy: 0.2500 - val_precision: 0.0000e+00
# Epoch 2/50
# 2/2 [==============================] - ETA: 0s - loss: 4.1536 - accuracy: 0.2656 - precision: 0.2667
# Epoch 2: accuracy improved from 0.20312 to 0.26562, saving model to DENCE.h5
# 2/2 [==============================] - 25s 19s/step - loss: 4.1536 - accuracy: 0.2656 - precision: 0.2667 - val_loss: 8.8285 - val_accuracy: 0.2188 - val_precision: 0.2188
# Epoch 3/50
# 2/2 [==============================] - ETA: 0s - loss: 3.5327 - accuracy: 0.1562 - precision: 0.2632
# Epoch 3: accuracy did not improve from 0.26562
# 2/2 [==============================] - 17s 10s/step - loss: 3.5327 - accuracy: 0.1562 - precision: 0.2632 - val_loss: 10.1990 - val_accuracy: 0.2500 - val_precision: 0.2381
# Epoch 4/50
# 2/2 [==============================] - ETA: 0s - loss: 2.1481 - accuracy: 0.2812 - precision: 0.3488
# Epoch 4: accuracy improved from 0.26562 to 0.28125, saving model to DENCE.h5
# 2/2 [==============================] - 18s 11s/step - loss: 2.1481 - accuracy: 0.2812 - precision: 0.3488 - val_loss: 13.7468 - val_accuracy: 0.3125 - val_precision: 0.3125
# Epoch 5/50
# 2/2 [==============================] - ETA: 0s - loss: 1.9520 - accuracy: 0.4688 - precision: 0.5814
# Epoch 5: accuracy improved from 0.28125 to 0.46875, saving model to DENCE.h5
# 2/2 [==============================] - 17s 11s/step - loss: 1.9520 - accuracy: 0.4688 - precision: 0.5814 - val_loss: 29.2920 - val_accuracy: 0.3906 - val_precision: 0.3906
# Epoch 6/50
# 2/2 [==============================] - ETA: 0s - loss: 2.9482 - accuracy: 0.3594 - precision: 0.6154
# Epoch 6: accuracy did not improve from 0.46875
# 2/2 [==============================] - 16s 9s/step - loss: 2.9482 - accuracy: 0.3594 - precision: 0.6154 - val_loss: 76.6261 - val_accuracy: 0.2812 - val_precision: 0.2812
# Epoch 7/50
# 2/2 [==============================] - ETA: 0s - loss: 1.6119 - accuracy: 0.4688 - precision: 0.6071
# Epoch 7: accuracy did not improve from 0.46875
# 2/2 [==============================] - 15s 9s/step - loss: 1.6119 - accuracy: 0.4688 - precision: 0.6071 - val_loss: 45.8130 - val_accuracy: 0.3594 - val_precision: 0.3387
# Epoch 8/50
# 2/2 [==============================] - ETA: 0s - loss: 2.7318 - accuracy: 0.4531 - precision: 0.5714
# Epoch 8: accuracy did not improve from 0.46875
# 2/2 [==============================] - 16s 9s/step - loss: 2.7318 - accuracy: 0.4531 - precision: 0.5714 - val_loss: 19.2946 - val_accuracy: 0.3125 - val_precision: 0.3091
# Epoch 9/50
# 2/2 [==============================] - ETA: 0s - loss: 1.7874 - accuracy: 0.3906 - precision: 0.6842
# Epoch 9: accuracy did not improve from 0.46875
# 2/2 [==============================] - 16s 9s/step - loss: 1.7874 - accuracy: 0.3906 - precision: 0.6842 - val_loss: 8.3648 - val_accuracy: 0.2812 - val_precision: 0.1613
# Epoch 10/50
# 2/2 [==============================] - ETA: 0s - loss: 2.0275 - accuracy: 0.3281 - precision: 0.2800
# Epoch 10: accuracy did not improve from 0.46875
# 2/2 [==============================] - 15s 9s/step - loss: 2.0275 - accuracy: 0.3281 - precision: 0.2800 - val_loss: 6.3394 - val_accuracy: 0.2656 - val_precision: 0.3333
# Epoch 11/50
# 2/2 [==============================] - ETA: 0s - loss: 1.6208 - accuracy: 0.4219 - precision: 0.5789
# Epoch 11: accuracy did not improve from 0.46875
# 2/2 [==============================] - 15s 9s/step - loss: 1.6208 - accuracy: 0.4219 - precision: 0.5789 - val_loss: 6.6070 - val_accuracy: 0.2344 - val_precision: 0.1471
# Epoch 12/50
# 2/2 [==============================] - ETA: 0s - loss: 1.4870 - accuracy: 0.5156 - precision: 0.6071
# Epoch 12: accuracy improved from 0.46875 to 0.51562, saving model to DENCE.h5
# 2/2 [==============================] - 18s 12s/step - loss: 1.4870 - accuracy: 0.5156 - precision: 0.6071 - val_loss: 9.8664 - val_accuracy: 0.1094 - val_precision: 0.0294
# Epoch 13/50
# 2/2 [==============================] - ETA: 0s - loss: 1.9995 - accuracy: 0.4219 - precision: 0.4857
# Epoch 13: accuracy did not improve from 0.51562
# 2/2 [==============================] - 15s 9s/step - loss: 1.9995 - accuracy: 0.4219 - precision: 0.4857 - val_loss: 16.1623 - val_accuracy: 0.0000e+00 - val_precision: 0.0000e+00
# Epoch 14/50
# 2/2 [==============================] - ETA: 0s - loss: 1.4833 - accuracy: 0.4688 - precision: 0.7037
# Epoch 14: accuracy did not improve from 0.51562
# 2/2 [==============================] - 15s 9s/step - loss: 1.4833 - accuracy: 0.4688 - precision: 0.7037 - val_loss: 21.6947 - val_accuracy: 0.1406 - val_precision: 0.1143
# Epoch 15/50
# 2/2 [==============================] - ETA: 0s - loss: 1.6357 - accuracy: 0.4688 - precision: 0.5926
# Epoch 15: accuracy did not improve from 0.51562
# 2/2 [==============================] - 16s 10s/step - loss: 1.6357 - accuracy: 0.4688 - precision: 0.5926 - val_loss: 23.9695 - val_accuracy: 0.0938 - val_precision: 0.0952
# Epoch 16/50
# 2/2 [==============================] - ETA: 0s - loss: 1.5688 - accuracy: 0.4844 - precision: 0.4595
# Epoch 16: accuracy did not improve from 0.51562
# 2/2 [==============================] - 16s 10s/step - loss: 1.5688 - accuracy: 0.4844 - precision: 0.4595 - val_loss: 31.0434 - val_accuracy: 0.1719 - val_precision: 0.1707
# Epoch 17/50
# 2/2 [==============================] - ETA: 0s - loss: 1.5005 - accuracy: 0.5000 - precision: 0.7188
# Epoch 17: accuracy did not improve from 0.51562
# 2/2 [==============================] - 17s 11s/step - loss: 1.5005 - accuracy: 0.5000 - precision: 0.7188 - val_loss: 35.4866 - val_accuracy: 0.0938 - val_precision: 0.1176
# Epoch 18/50
# 2/2 [==============================] - ETA: 0s - loss: 1.6558 - accuracy: 0.4688 - precision: 0.5882
# Epoch 18: accuracy did not improve from 0.51562
# 2/2 [==============================] - 19s 10s/step - loss: 1.6558 - accuracy: 0.4688 - precision: 0.5882 - val_loss: 49.6087 - val_accuracy: 0.0781 - val_precision: 0.0755
# Epoch 19/50
# 2/2 [==============================] - ETA: 0s - loss: 1.7646 - accuracy: 0.3594 - precision: 0.5172
# Epoch 19: accuracy did not improve from 0.51562
# 2/2 [==============================] - 17s 10s/step - loss: 1.7646 - accuracy: 0.3594 - precision: 0.5172 - val_loss: 20.7105 - val_accuracy: 0.1406 - val_precision: 0.0625
# Epoch 20/50
# 2/2 [==============================] - ETA: 0s - loss: 2.0277 - accuracy: 0.4844 - precision: 0.5385
# Epoch 20: accuracy did not improve from 0.51562
# 2/2 [==============================] - 16s 10s/step - loss: 2.0277 - accuracy: 0.4844 - precision: 0.5385 - val_loss: 4.8516 - val_accuracy: 0.1406 - val_precision: 0.2105
# Epoch 21/50
# 2/2 [==============================] - ETA: 0s - loss: 1.9116 - accuracy: 0.5625 - precision: 0.6667
# Epoch 21: accuracy improved from 0.51562 to 0.56250, saving model to DENCE.h5
# 2/2 [==============================] - 17s 11s/step - loss: 1.9116 - accuracy: 0.5625 - precision: 0.6667 - val_loss: 7.9538 - val_accuracy: 0.1719 - val_precision: 0.0526
# Epoch 22/50
# 2/2 [==============================] - ETA: 0s - loss: 1.3516 - accuracy: 0.5938 - precision: 0.6333
# Epoch 22: accuracy improved from 0.56250 to 0.59375, saving model to DENCE.h5
# 2/2 [==============================] - 17s 11s/step - loss: 1.3516 - accuracy: 0.5938 - precision: 0.6333 - val_loss: 13.9927 - val_accuracy: 0.1406 - val_precision: 0.1667
# Epoch 23/50
# 2/2 [==============================] - ETA: 0s - loss: 1.4426 - accuracy: 0.5625 - precision: 0.6667
# Epoch 23: accuracy did not improve from 0.59375
# 2/2 [==============================] - 15s 9s/step - loss: 1.4426 - accuracy: 0.5625 - precision: 0.6667 - val_loss: 2.6888 - val_accuracy: 0.0938 - val_precision: 0.0000e+00
# Epoch 24/50
# 2/2 [==============================] - ETA: 0s - loss: 1.2856 - accuracy: 0.5938 - precision: 0.7179
# Epoch 24: accuracy did not improve from 0.59375
# 2/2 [==============================] - 15s 9s/step - loss: 1.2856 - accuracy: 0.5938 - precision: 0.7179 - val_loss: 2.5793 - val_accuracy: 0.2031 - val_precision: 0.0000e+00
# Epoch 25/50
# 2/2 [==============================] - ETA: 0s - loss: 1.5602 - accuracy: 0.5000 - precision: 0.6500
# Epoch 25: accuracy did not improve from 0.59375
# 2/2 [==============================] - 15s 9s/step - loss: 1.5602 - accuracy: 0.5000 - precision: 0.6500 - val_loss: 2.5497 - val_accuracy: 0.1875 - val_precision: 0.0000e+00
# Epoch 26/50
# 2/2 [==============================] - ETA: 0s - loss: 1.3771 - accuracy: 0.4844 - precision: 0.5789
# Epoch 26: accuracy did not improve from 0.59375
# 2/2 [==============================] - 16s 10s/step - loss: 1.3771 - accuracy: 0.4844 - precision: 0.5789 - val_loss: 2.3638 - val_accuracy: 0.1875 - val_precision: 0.0000e+00
# Epoch 27/50
# 2/2 [==============================] - ETA: 0s - loss: 1.6336 - accuracy: 0.5469 - precision: 0.6905
# Epoch 27: accuracy did not improve from 0.59375
# 2/2 [==============================] - 17s 11s/step - loss: 1.6336 - accuracy: 0.5469 - precision: 0.6905 - val_loss: 2.4552 - val_accuracy: 0.1719 - val_precision: 0.0000e+00
# Epoch 28/50
# 2/2 [==============================] - ETA: 0s - loss: 0.9657 - accuracy: 0.7031 - precision: 0.7500
# Epoch 28: accuracy improved from 0.59375 to 0.70312, saving model to DENCE.h5
# 2/2 [==============================] - 19s 13s/step - loss: 0.9657 - accuracy: 0.7031 - precision: 0.7500 - val_loss: 2.2563 - val_accuracy: 0.1875 - val_precision: 0.0000e+00
# Epoch 29/50
# 2/2 [==============================] - ETA: 0s - loss: 1.1222 - accuracy: 0.6094 - precision: 0.7576
# Epoch 29: accuracy did not improve from 0.70312
# 2/2 [==============================] - 16s 9s/step - loss: 1.1222 - accuracy: 0.6094 - precision: 0.7576 - val_loss: 2.4154 - val_accuracy: 0.1406 - val_precision: 0.0000e+00
# Epoch 30/50
# 2/2 [==============================] - ETA: 0s - loss: 1.6193 - accuracy: 0.4844 - precision: 0.8276
# Epoch 30: accuracy did not improve from 0.70312
# 2/2 [==============================] - 15s 9s/step - loss: 1.6193 - accuracy: 0.4844 - precision: 0.8276 - val_loss: 2.2218 - val_accuracy: 0.1562 - val_precision: 1.0000
# Epoch 31/50
# 2/2 [==============================] - ETA: 0s - loss: 1.4391 - accuracy: 0.5938 - precision: 0.6842
# Epoch 31: accuracy did not improve from 0.70312
# 2/2 [==============================] - 15s 9s/step - loss: 1.4391 - accuracy: 0.5938 - precision: 0.6842 - val_loss: 2.0542 - val_accuracy: 0.2656 - val_precision: 0.0000e+00
# Epoch 32/50
# 2/2 [==============================] - ETA: 0s - loss: 1.3900 - accuracy: 0.5000 - precision: 0.5714
# Epoch 32: accuracy did not improve from 0.70312
# 2/2 [==============================] - 16s 10s/step - loss: 1.3900 - accuracy: 0.5000 - precision: 0.5714 - val_loss: 2.6302 - val_accuracy: 0.0781 - val_precision: 0.0000e+00
# Epoch 33/50
# 2/2 [==============================] - ETA: 0s - loss: 1.2342 - accuracy: 0.5156 - precision: 0.7667
# Epoch 33: accuracy did not improve from 0.70312
# 2/2 [==============================] - 15s 9s/step - loss: 1.2342 - accuracy: 0.5156 - precision: 0.7667 - val_loss: 2.7128 - val_accuracy: 0.1094 - val_precision: 0.0000e+00
# Epoch 34/50
# 2/2 [==============================] - ETA: 0s - loss: 1.1173 - accuracy: 0.5938 - precision: 0.7250
# Epoch 34: accuracy did not improve from 0.70312
# 2/2 [==============================] - 15s 9s/step - loss: 1.1173 - accuracy: 0.5938 - precision: 0.7250 - val_loss: 2.5751 - val_accuracy: 0.0781 - val_precision: 0.0000e+00
# Epoch 35/50
# 2/2 [==============================] - ETA: 0s - loss: 1.3558 - accuracy: 0.4375 - precision: 0.5128
# Epoch 35: accuracy did not improve from 0.70312
# 2/2 [==============================] - 16s 10s/step - loss: 1.3558 - accuracy: 0.4375 - precision: 0.5128 - val_loss: 2.7115 - val_accuracy: 0.0625 - val_precision: 0.0000e+00
# Epoch 36/50
# 2/2 [==============================] - ETA: 0s - loss: 1.1425 - accuracy: 0.6250 - precision: 0.7838
# Epoch 36: accuracy did not improve from 0.70312
# 2/2 [==============================] - 16s 10s/step - loss: 1.1425 - accuracy: 0.6250 - precision: 0.7838 - val_loss: 2.5032 - val_accuracy: 0.1250 - val_precision: 0.0000e+00
# Epoch 37/50
# 2/2 [==============================] - ETA: 0s - loss: 1.3024 - accuracy: 0.6406 - precision: 0.7500
# Epoch 37: accuracy did not improve from 0.70312
# 2/2 [==============================] - 18s 11s/step - loss: 1.3024 - accuracy: 0.6406 - precision: 0.7500 - val_loss: 2.7230 - val_accuracy: 0.0781 - val_precision: 0.0000e+00
# Epoch 38/50
# 2/2 [==============================] - ETA: 0s - loss: 1.3951 - accuracy: 0.4688 - precision: 0.6071
# Epoch 38: accuracy did not improve from 0.70312
# 2/2 [==============================] - 17s 11s/step - loss: 1.3951 - accuracy: 0.4688 - precision: 0.6071 - val_loss: 2.5526 - val_accuracy: 0.0625 - val_precision: 0.0000e+00
# Epoch 39/50
# 2/2 [==============================] - ETA: 0s - loss: 1.2005 - accuracy: 0.5781 - precision: 0.7027
# Epoch 39: accuracy did not improve from 0.70312
# 2/2 [==============================] - 15s 9s/step - loss: 1.2005 - accuracy: 0.5781 - precision: 0.7027 - val_loss: 2.3741 - val_accuracy: 0.0625 - val_precision: 0.0000e+00
# Epoch 40/50
# 2/2 [==============================] - ETA: 0s - loss: 1.0923 - accuracy: 0.6250 - precision: 0.8387
# Epoch 40: accuracy did not improve from 0.70312
# 2/2 [==============================] - 16s 10s/step - loss: 1.0923 - accuracy: 0.6250 - precision: 0.8387 - val_loss: 2.6735 - val_accuracy: 0.0625 - val_precision: 0.0000e+00
# Epoch 41/50
# 2/2 [==============================] - ETA: 0s - loss: 1.1016 - accuracy: 0.5625 - precision: 0.7576
# Epoch 41: accuracy did not improve from 0.70312
# 2/2 [==============================] - 15s 9s/step - loss: 1.1016 - accuracy: 0.5625 - precision: 0.7576 - val_loss: 2.5833 - val_accuracy: 0.1094 - val_precision: 0.0000e+00
# Epoch 42/50
# 2/2 [==============================] - ETA: 0s - loss: 1.2233 - accuracy: 0.5938 - precision: 0.6923
# Epoch 42: accuracy did not improve from 0.70312
# 2/2 [==============================] - 15s 9s/step - loss: 1.2233 - accuracy: 0.5938 - precision: 0.6923 - val_loss: 2.6884 - val_accuracy: 0.0938 - val_precision: 0.0000e+00
# Epoch 43/50
# 2/2 [==============================] - ETA: 0s - loss: 1.8041 - accuracy: 0.6250 - precision: 0.7027
# Epoch 43: accuracy did not improve from 0.70312
# 2/2 [==============================] - 15s 9s/step - loss: 1.8041 - accuracy: 0.6250 - precision: 0.7027 - val_loss: 2.8636 - val_accuracy: 0.1250 - val_precision: 0.0000e+00
# Epoch 44/50
# 2/2 [==============================] - ETA: 0s - loss: 1.5528 - accuracy: 0.5625 - precision: 0.6222
# Epoch 44: accuracy did not improve from 0.70312
# 2/2 [==============================] - 15s 9s/step - loss: 1.5528 - accuracy: 0.5625 - precision: 0.6222 - val_loss: 2.9381 - val_accuracy: 0.1406 - val_precision: 0.0000e+00
# Epoch 45/50
# 2/2 [==============================] - ETA: 0s - loss: 2.0107 - accuracy: 0.5938 - precision: 0.5962
# Epoch 45: accuracy did not improve from 0.70312
# 2/2 [==============================] - 16s 10s/step - loss: 2.0107 - accuracy: 0.5938 - precision: 0.5962 - val_loss: 2.8933 - val_accuracy: 0.1562 - val_precision: 0.0000e+00
# Epoch 46/50
# 2/2 [==============================] - ETA: 0s - loss: 1.5637 - accuracy: 0.5312 - precision: 0.6222
# Epoch 46: accuracy did not improve from 0.70312
# 2/2 [==============================] - 17s 10s/step - loss: 1.5637 - accuracy: 0.5312 - precision: 0.6222 - val_loss: 2.8981 - val_accuracy: 0.1875 - val_precision: 0.0000e+00
# Epoch 47/50
# 2/2 [==============================] - ETA: 0s - loss: 1.4272 - accuracy: 0.5312 - precision: 0.5745
# Epoch 47: accuracy did not improve from 0.70312
# 2/2 [==============================] - 17s 10s/step - loss: 1.4272 - accuracy: 0.5312 - precision: 0.5745 - val_loss: 2.7329 - val_accuracy: 0.2031 - val_precision: 0.0000e+00
# Epoch 48/50
# 2/2 [==============================] - ETA: 0s - loss: 1.3750 - accuracy: 0.6250 - precision: 0.7273
# Epoch 48: accuracy did not improve from 0.70312
# 2/2 [==============================] - 16s 9s/step - loss: 1.3750 - accuracy: 0.6250 - precision: 0.7273 - val_loss: 2.8456 - val_accuracy: 0.0781 - val_precision: 0.0000e+00
# Epoch 49/50
# 2/2 [==============================] - ETA: 0s - loss: 1.1409 - accuracy: 0.5938 - precision: 0.7179
# Epoch 49: accuracy did not improve from 0.70312
# 2/2 [==============================] - 16s 9s/step - loss: 1.1409 - accuracy: 0.5938 - precision: 0.7179 - val_loss: 2.7887 - val_accuracy: 0.0625 - val_precision: 0.0000e+00
# Epoch 50/50
# 2/2 [==============================] - ETA: 0s - loss: 1.7110 - accuracy: 0.5938 - precision: 0.7778
# Epoch 50: accuracy did not improve from 0.70312
# 2/2 [==============================] - 16s 10s/step - loss: 1.7110 - accuracy: 0.5938 - precision: 0.7778 - val_loss: 2.6885 - val_accuracy: 0.1406 - val_precision: 0.0000e+00
# 3/3 [==============================] - ETA: 0s - loss: 0.2328 - accuracy: 0.8875 - precision: 0.8861
# Epoch 49: accuracy did not improve from 0.94792
# 3/3 [==============================] - 43s 14s/step - loss: 0.2328 - accuracy: 0.8875 - precision: 0.8861 - val_loss: 7.1945 - val_accuracy: 0.3438 - val_precision: 0.3438
# Epoch 50/50
# 3/3 [==============================] - ETA: 0s - loss: 0.2583 - accuracy: 0.8958 - precision: 0.8958
# Epoch 50: accuracy did not improve from 0.94792
# 3/3 [==============================] - 47s 17s/step - loss: 0.2583 - accuracy: 0.8958 - precision: 0.8958 - val_loss: 4.1310 - val_accuracy: 0.3333 - val_precision: 0.3333

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'precision', 'val_loss', 'val_accuracy', 'val_precision'])

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(20, 8))
plt.plot(history.history['accuracy'])

for i in range(epochs):
    if i%5 == 0:
        plt.annotate(np.round(history.history['accuracy'][i]*100,2),xy=(i,history.history['accuracy'][i]))

plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.show()

# %%
plt.figure(figsize=(20, 8))
plt.plot(history.history['loss'])

for i in range(epochs):
    if i%5 == 0:
        plt.annotate(np.round(history.history['loss'][i]*100,2),xy=(i,history.history['loss'][i]))

plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.show()
